# %%
import sys
# !{sys.executable} -m pip install git+https://github.com/aparrish/vsketch
# Out:
# Collecting git+https://github.com/aparrish/vsketch
#   Cloning https://github.com/aparrish/vsketch to /private/var/folders/64/84sz_vl56q9bw0rj8l_68_c00000gn/T/pip-req-build-da7w31yr
#   Running command git clone --filter=blob:none --quiet https://github.com/aparrish/vsketch /private/var/folders/64/84sz_vl56q9bw0rj8l_68_c00000gn/T/pip-req-build-da7w31yr
#   Resolved https://github.com/aparrish/vsketch to commit 852a0aa516fe021e230e277de1b3ca8314cbb10b
#   Installing build dependencies ... one
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting vpype@ git+https://github.com/abey79/vpype/@master (from vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0)
#   Cloning https://github.com/abey79/vpype/ (to revision master) to /private/var/folders/64/84sz_vl56q9bw0rj8l_68_c00000gn/T/pip-install-g_gpnhv4/vpype_5530e18c20e64f4d92734ac48d8336bd
#   Running command git clone --filter=blob:none --quiet https://github.com/abey79/vpype/ /private/var/folders/64/84sz_vl56q9bw0rj8l_68_c00000gn/T/pip-install-g_gpnhv4/vpype_5530e18c20e64f4d92734ac48d8336bd
#   Resolved https://github.com/abey79/vpype/ to commit 3dbc352d3e4f37c20ff3d28e7f56235da2c139ed
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting PySide6>=6.3.2 (from vsketch==1.1.0)
#   Downloading PySide6-6.9.0-cp39-abi3-macosx_12_0_universal2.whl.metadata (5.5 kB)
# Collecting Shapely>=1.8.2 (from Shapely[vectorized]>=1.8.2->vsketch==1.1.0)
#   Downloading shapely-2.1.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting cookiecutter>=2.1 (from vsketch==1.1.0)
#   Downloading cookiecutter-2.6.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting matplotlib>=3.3.3 (from vsketch==1.1.0)
#   Downloading matplotlib-3.10.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting multiprocess>=0.70 (from vsketch==1.1.0)
#   Downloading multiprocess-0.70.17-py313-none-any.whl.metadata (7.2 kB)
# Collecting numpy<3,>=1.20.1 (from vsketch==1.1.0)
#   Downloading numpy-2.2.4-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting pnoise>=0.2.0 (from vsketch==1.1.0)
#   Downloading pnoise-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting watchfiles>=0.12 (from vsketch==1.1.0)
#   Downloading watchfiles-1.0.4-cp313-cp313-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting binaryornot>=0.4.4 (from cookiecutter>=2.1->vsketch==1.1.0)
#   Downloading binaryornot-0.4.4-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cookiecutter>=2.1->vsketch==1.1.0) (3.1.5)
# Collecting click<9.0.0,>=7.0 (from cookiecutter>=2.1->vsketch==1.1.0)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cookiecutter>=2.1->vsketch==1.1.0) (6.0.2)
# Collecting python-slugify>=4.0.0 (from cookiecutter>=2.1->vsketch==1.1.0)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests>=2.23.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cookiecutter>=2.1->vsketch==1.1.0) (2.32.3)
# Requirement already satisfied: arrow in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cookiecutter>=2.1->vsketch==1.1.0) (1.3.0)
# Collecting rich (from cookiecutter>=2.1->vsketch==1.1.0)
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.3.3->vsketch==1.1.0)
#   Downloading contourpy-1.3.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.3.3->vsketch==1.1.0)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.3.3->vsketch==1.1.0)
#   Downloading fonttools-4.57.0-cp313-cp313-macosx_10_13_universal2.whl.metadata (102 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.3.3->vsketch==1.1.0)
#   Downloading kiwisolver-1.4.8-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.2 kB)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.3->vsketch==1.1.0) (24.2)
# Collecting pillow>=8 (from matplotlib>=3.3.3->vsketch==1.1.0)
#   Downloading pillow-11.1.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.3.3->vsketch==1.1.0)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.3->vsketch==1.1.0) (2.9.0.post0)
# Collecting dill>=0.3.9 (from multiprocess>=0.70->vsketch==1.1.0)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Collecting shiboken6==6.9.0 (from PySide6>=6.3.2->vsketch==1.1.0)
#   Downloading shiboken6-6.9.0-cp39-abi3-macosx_12_0_universal2.whl.metadata (2.7 kB)
# Collecting PySide6-Essentials==6.9.0 (from PySide6>=6.3.2->vsketch==1.1.0)
#   Downloading PySide6_Essentials-6.9.0-cp39-abi3-macosx_12_0_universal2.whl.metadata (3.9 kB)
# Collecting PySide6-Addons==6.9.0 (from PySide6>=6.3.2->vsketch==1.1.0)
#   Downloading PySide6_Addons-6.9.0-cp39-abi3-macosx_12_0_universal2.whl.metadata (4.2 kB)
# WARNING: shapely 2.1.0 does not provide the extra 'vectorized'
# Requirement already satisfied: anyio>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from watchfiles>=0.12->vsketch==1.1.0) (4.8.0)
# Collecting asteval>=0.9.26 (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0)
#   Downloading asteval-1.0.6-py3-none-any.whl.metadata (6.2 kB)
# Collecting cachetools>=4.2.2 (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyphen<0.16,>=0.14 (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0)
#   Downloading pyphen-0.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting scipy>=1.6 (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0)
#   Downloading scipy-1.15.2-cp313-cp313-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting svgelements>=1.6.10 (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0)
#   Downloading svgelements-1.9.6-py2.py3-none-any.whl.metadata (44 kB)
# Collecting svgwrite<2.0,>=1.4 (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0)
#   Downloading svgwrite-1.4.3-py3-none-any.whl.metadata (8.8 kB)
# Collecting tomli>=2.0.0 (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0)
#   Downloading tomli-2.2.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting glcontext>=2.3.2 (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0)
#   Downloading glcontext-3.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.0 kB)
# Collecting moderngl!=5.7.1,!=5.7.2,>=5.6.2 (from vpype@ git+https://github.com/abey79/vpype/@master->vpype[all]@ git+https://github.com/abey79/vpype/@master->vsketch==1.1.0)
#   Downloading moderngl-5.12.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.8 kB)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio>=3.0.0->watchfiles>=0.12->vsketch==1.1.0) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio>=3.0.0->watchfiles>=0.12->vsketch==1.1.0) (1.3.1)
# Collecting chardet>=3.0.2 (from binaryornot>=0.4.4->cookiecutter>=2.1->vsketch==1.1.0)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from Jinja2<4.0.0,>=2.7->cookiecutter>=2.1->vsketch==1.1.0) (3.0.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.3->vsketch==1.1.0) (1.17.0)
# Collecting text-unidecode>=1.3 (from python-slugify>=4.0.0->cookiecutter>=2.1->vsketch==1.1.0)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->cookiecutter>=2.1->vsketch==1.1.0) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->cookiecutter>=2.1->vsketch==1.1.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.23.0->cookiecutter>=2.1->vsketch==1.1.0) (2024.12.14)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from arrow->cookiecutter>=2.1->vsketch==1.1.0) (2.9.0.20241206)
# Collecting markdown-it-py>=2.2.0 (from rich->cookiecutter>=2.1->vsketch==1.1.0)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rich->cookiecutter>=2.1->vsketch==1.1.0) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->cookiecutter>=2.1->vsketch==1.1.0)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading cookiecutter-2.6.0-py3-none-any.whl (39 kB)
# Downloading matplotlib-3.10.1-cp313-cp313-macosx_11_0_arm64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 14.5 MB/s eta 0:00:00a 0:00:01
# Downloading multiprocess-0.70.17-py313-none-any.whl (149 kB)
# Downloading numpy-2.2.4-cp313-cp313-macosx_14_0_arm64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 12.1 MB/s eta 0:00:00a 0:00:01
# Downloading pnoise-0.2.0-py3-none-any.whl (13 kB)
# Downloading PySide6-6.9.0-cp39-abi3-macosx_12_0_universal2.whl (558 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 558.0/558.0 kB 9.7 MB/s eta 0:00:00
# Downloading PySide6_Addons-6.9.0-cp39-abi3-macosx_12_0_universal2.whl (315.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.6/315.6 MB 14.9 MB/s eta 0:00:0000:0100:01
# Downloading PySide6_Essentials-6.9.0-cp39-abi3-macosx_12_0_universal2.whl (132.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 MB 14.9 MB/s eta 0:00:0000:0100:01
# Downloading shiboken6-6.9.0-cp39-abi3-macosx_12_0_universal2.whl (407 kB)
# Downloading shapely-2.1.0-cp313-cp313-macosx_11_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.0 MB/s eta 0:00:00
# Downloading watchfiles-1.0.4-cp313-cp313-macosx_11_0_arm64.whl (381 kB)
# Downloading asteval-1.0.6-py3-none-any.whl (22 kB)
# Downloading binaryornot-0.4.4-py2.py3-none-any.whl (9.0 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading contourpy-1.3.1-cp313-cp313-macosx_11_0_arm64.whl (255 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
# Downloading fonttools-4.57.0-cp313-cp313-macosx_10_13_universal2.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 14.5 MB/s eta 0:00:00
# Downloading glcontext-3.0.0-cp313-cp313-macosx_11_0_arm64.whl (9.7 kB)
# Downloading kiwisolver-1.4.8-cp313-cp313-macosx_11_0_arm64.whl (65 kB)
# Downloading moderngl-5.12.0-cp313-cp313-macosx_11_0_arm64.whl (109 kB)
# Downloading pillow-11.1.0-cp313-cp313-macosx_11_0_arm64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 11.8 MB/s eta 0:00:00a 0:00:01
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading pyphen-0.15.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.3 MB/s eta 0:00:00
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading scipy-1.15.2-cp313-cp313-macosx_14_0_arm64.whl (22.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 11.5 MB/s eta 0:00:00a 0:00:01
# Downloading svgelements-1.9.6-py2.py3-none-any.whl (137 kB)
# Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
# Downloading tomli-2.2.1-cp313-cp313-macosx_11_0_arm64.whl (123 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: vsketch, vpype
#   Building wheel for vsketch (pyproject.toml) ... done
#   Created wheel for vsketch: filename=vsketch-1.1.0-py3-none-any.whl size=59747 sha256=a4cbdeb478ed6f7025163294903711244fca1836e82afddd50287582a2305759
#   Stored in directory: /private/var/folders/64/84sz_vl56q9bw0rj8l_68_c00000gn/T/pip-ephem-wheel-cache-uas18jcm/wheels/79/f8/b8/84e3d85cfd60b23bb4f9a035b3c4623c64f6bf174c33e25883
#   Building wheel for vpype (pyproject.toml) ... done
#   Created wheel for vpype: filename=vpype-1.15.0a0-py3-none-any.whl size=527345 sha256=0cb707d2b1090d39087bf0cdb600dbbfdb44b1b880b737f14be071002ca26af9
#   Stored in directory: /private/var/folders/64/84sz_vl56q9bw0rj8l_68_c00000gn/T/pip-ephem-wheel-cache-uas18jcm/wheels/77/2f/98/0caa1cd08175a72801d26311bbe3522125a572dda70c3c64dd
# Successfully built vsketch vpype
# Installing collected packages: text-unidecode, svgelements, glcontext, tomli, svgwrite, shiboken6, python-slugify, pyphen, pyparsing, pillow, numpy, moderngl, mdurl, kiwisolver, fonttools, dill, cycler, click, chardet, cachetools, asteval, watchfiles, Shapely, scipy, PySide6-Essentials, pnoise, multiprocess, markdown-it-py, contourpy, binaryornot, vpype, rich, PySide6-Addons, matplotlib, PySide6, cookiecutter, vsketch
# Successfully installed PySide6-6.9.0 PySide6-Addons-6.9.0 PySide6-Essentials-6.9.0 Shapely-2.1.0 asteval-1.0.6 binaryornot-0.4.4 cachetools-5.5.2 chardet-5.2.0 click-8.1.8 contourpy-1.3.1 cookiecutter-2.6.0 cycler-0.12.1 dill-0.3.9 fonttools-4.57.0 glcontext-3.0.0 kiwisolver-1.4.8 markdown-it-py-3.0.0 matplotlib-3.10.1 mdurl-0.1.2 moderngl-5.12.0 multiprocess-0.70.17 numpy-2.2.4 pillow-11.1.0 pnoise-0.2.0 pyparsing-3.2.3 pyphen-0.15.0 python-slugify-8.0.4 rich-14.0.0 scipy-1.15.2 shiboken6-6.9.0 svgelements-1.9.6 svgwrite-1.4.3 text-unidecode-1.3 tomli-2.2.1 vpype-1.15.0a0 vsketch-1.1.0 watchfiles-1.0.4
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install --upgrade https://github.com/aparrish/bezmerizing/archive/main.zip
# Out:
# Collecting https://github.com/aparrish/bezmerizing/archive/main.zip
#   Downloading https://github.com/aparrish/bezmerizing/archive/main.zip
#      - 242.6 kB 6.3 MB/s 0:00:00
#   Installing build dependencies ... one
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scipy>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from bezmerizing==0.2.0) (1.15.2)
# Requirement already satisfied: numpy>=1.16.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from bezmerizing==0.2.0) (2.2.4)
# Building wheels for collected packages: bezmerizing
#   Building wheel for bezmerizing (pyproject.toml) ... done
#   Created wheel for bezmerizing: filename=bezmerizing-0.2.0-py3-none-any.whl size=12898 sha256=67c4e51ea90535cc72e9f91ac7fe00e0ae34834872273b17f1af59671146d6b4
#   Stored in directory: /private/var/folders/64/84sz_vl56q9bw0rj8l_68_c00000gn/T/pip-ephem-wheel-cache-6ttlixpa/wheels/96/4c/0d/16b63492acd91653b43171152cb93cdd63c53ad8ccea1b27b3
# Successfully built bezmerizing
# Installing collected packages: bezmerizing
# Successfully installed bezmerizing-0.2.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip

# %%
import random
import vsketch
import bezmerizing
# Out:
# WARNING:matplotlib.font_manager:Matplotlib is building the font cache; this may take a moment.

# %%
from numpy.random import uniform, normal, choice
import numpy as np

# %%
from scipy.stats import truncnorm
def t_normal(a, b, mu, sigma):
    tn = truncnorm((a-mu)/sigma, (b-mu)/sigma, loc=mu, scale=sigma)
    return tn.rvs(1)[0]

# %%
def uniform_glyph_baseline(n=10):
    pts = [[-0.4, 0.5], [0.4, 0.5]]
    for i in range(n):
        pts.append([uniform(-0.5, 0.5), uniform(-0.5, 0.5)])
    return pts

# %%
# parameters for the grid---play with these values!
width = 100
height = 100
grid_size = 10

# calculate how large each "cell" of the grid is
cell_size_x = width / grid_size
cell_size_y = height / grid_size

# how much to scale the grid: size of cell times a multiplier
# (multiplier controls how much space in the cell the glyph will take up)
scale_val = (width / grid_size) * 0.6

vsk = vsketch.Vsketch()
vsk.size(f"{width}mm", f"{height}mm")
vsk.scale("1mm")

for i in range(grid_size):
    for j in range(grid_size):
        glyph = uniform_glyph_baseline(random.randrange(4, 12))
        with vsk.pushMatrix():
            vsk.translate(i * cell_size_x, j * cell_size_y)
            vsk.scale(scale_val)
            vsk.polygon(glyph)

vsk.display()

# %%
def make_scribble(width, height, steps, stddev=0):
    pts = []
    for i in range(steps):
        x = ((width / steps) * i) + normal(0, stddev)
        y = normal(0, height)
        pts.append([x, y])
    return pts

# %%
vsk = vsketch.Vsketch()
vsk.size("200mm", "320mm")
vsk.scale("1mm")
for i in range(15):
    pts = make_scribble(width=180, height=5, steps=int(uniform(25, 100)), stddev=i * 0.5)
    curve_pts = bezmerizing.Polyline(pts).catmull_spline(tightness=uniform(-4, 1)).to_polyline(10)
    vsk.strokeWeight(choice([1, 2, 3]))
    with vsk.pushMatrix():
        vsk.translate(0, i * 20)
        vsk.polygon(curve_pts)
vsk.display(fig_size=(6, 10))

# %%
import vsketch
import random
from copy import deepcopy

width = 100
height = 100
grid_size = 10

cell_size_x = width / grid_size
cell_size_y = height / grid_size

scale_val = (width / grid_size) * 0.5

def asemic_glyph():
    glyph = []
    num_points = random.randint(3, 6)
    for _ in range(num_points):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)
        glyph.append((x, y))
    return glyph

vsk = vsketch.Vsketch()
vsk.size(f"{width}mm", f"{height}mm")
vsk.scale("1mm")

base_glyphs = [asemic_glyph() for _ in range(5)]

for j in range(grid_size):
    line_length = random.randint(4, grid_size)
    for i in range(line_length):
        x_offset = (j % 2) * (cell_size_x * 0.4)
        glyph = deepcopy(random.choice(base_glyphs))

        glyph = [(x + random.uniform(-0.1, 0.1), y + random.uniform(-0.1, 0.1)) for x, y in glyph]

        with vsk.pushMatrix():
            vsk.translate(i * cell_size_x + x_offset, j * cell_size_y)
            vsk.scale(scale_val)
            vsk.rotate(random.uniform(-0.3, 0.3))
            vsk.polygon(glyph)

            if random.random() < 0.3:
                vsk.fill(1)
                dot_size = random.uniform(0.2, 0.5)
                vsk.circle(random.uniform(-0.5, 0.5), random.uniform(-0.5, 0.5), dot_size)
                vsk.fill(0)

vsk.display()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 47
#      45                 dot_size = random.uniform(0.2, 0.5)
#      46                 vsk.circle(random.uniform(-0.5, 0.5), random.uniform(-0.5, 0.5), dot_size)
# ---> 47                 vsk.fill(0)
#      49 vsk.display()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/vsketch/vsketch.py:288, in Vsketch.fill(self, c)
#     283 """Set the current fill color.
#     284 Args:
#     285     c (strictly positive int): the color (e.g. layer) to use for fill
#     286 """
#     287 if c < 1:
# --> 288     raise ValueError("color layer must be strictly positive")
#     290 self._cur_fill = c
#
# ValueError: color layer must be strictly positive

# %%
import vsketch
import random
from copy import deepcopy

width = 100
height = 100
grid_size = 10

cell_size_x = width / grid_size
cell_size_y = height / grid_size

scale_val = (width / grid_size) * 0.5

def asemic_glyph():
    glyph = []
    num_points = random.randint(3, 6)
    for _ in range(num_points):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)
        glyph.append((x, y))
    return glyph

vsk = vsketch.Vsketch()
vsk.size(f"{width}mm", f"{height}mm")
vsk.scale("1mm")

base_glyphs = [asemic_glyph() for _ in range(5)]

for j in range(grid_size):
    line_length = random.randint(4, grid_size)
    for i in range(line_length):
        x_offset = (j % 2) * (cell_size_x * 0.4)
        glyph = deepcopy(random.choice(base_glyphs))

        glyph = [(x + random.uniform(-0.1, 0.1), y + random.uniform(-0.1, 0.1)) for x, y in glyph]

        with vsk.pushMatrix():
            vsk.translate(i * cell_size_x + x_offset, j * cell_size_y)
            vsk.scale(scale_val)
            vsk.rotate(random.uniform(-0.3, 0.3))
            vsk.polygon(glyph)

            if random.random() < 0.3:
                vsk.strokeWeight(random.uniform(0.3, 0.7))
                vsk.circle(random.uniform(-0.5, 0.5), random.uniform(-0.5, 0.5), random.uniform(0.1, 0.4))

vsk.display()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 44
#      41             vsk.polygon(glyph)
#      43             if random.random() < 0.3:
# ---> 44                 vsk.strokeWeight(random.uniform(0.3, 0.7))
#      45                 vsk.circle(random.uniform(-0.5, 0.5), random.uniform(-0.5, 0.5), random.uniform(0.1, 0.4))
#      47 vsk.display()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/vsketch/vsketch.py:256, in Vsketch.strokeWeight(self, weight)
#     239 """Set the stroke weight.
#     240
#     241 By default, stroke are plotted with a single line. Stroke can be made thicker by
#    (...)
#     252     weight (strictly positive ``int``): number of plotted lines to use for strokes
#     253 """
#     255 if weight < 1:
# --> 256     raise ValueError("width should be a strictly positive integer")
#     257 self._stroke_weight = weight
#
# ValueError: width should be a strictly positive integer

# %%
import vsketch
import random
from copy import deepcopy

width = 100
height = 100
grid_size = 10

cell_size_x = width / grid_size
cell_size_y = height / grid_size

scale_val = (width / grid_size) * 0.5

def asemic_glyph():
    glyph = []
    num_points = random.randint(3, 6)
    for _ in range(num_points):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)
        glyph.append((x, y))
    return glyph

vsk = vsketch.Vsketch()
vsk.size(f"{width}mm", f"{height}mm")
vsk.scale("1mm")

base_glyphs = [asemic_glyph() for _ in range(5)]

for j in range(grid_size):
    line_length = random.randint(4, grid_size)
    for i in range(line_length):
        x_offset = (j % 2) * (cell_size_x * 0.4)
        glyph = deepcopy(random.choice(base_glyphs))

        glyph = [(x + random.uniform(-0.1, 0.1), y + random.uniform(-0.1, 0.1)) for x, y in glyph]

        with vsk.pushMatrix():
            vsk.translate(i * cell_size_x + x_offset, j * cell_size_y)
            vsk.scale(scale_val)
            vsk.rotate(random.uniform(-0.3, 0.3))
            vsk.polygon(glyph)

            if random.random() < 0.3:
                x = random.uniform(-0.3, 0.3)
                y = random.uniform(-0.3, 0.3)
                r = random.uniform(0.05, 0.2)
                vsk.line(x - r, y - r, x + r, y + r)

vsk.display()

# %%
import vsketch
import random
import math
from copy import deepcopy

width = 100
height = 100
grid_size = 10

cell_size_x = width / grid_size
cell_size_y = height / grid_size

scale_val = (width / grid_size) * 0.5

def asemic_glyph():
    glyph = []
    num_points = random.randint(3, 6)
    for _ in range(num_points):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)
        glyph.append((x, y))
    return glyph

vsk = vsketch.Vsketch()
vsk.size(f"{width}mm", f"{height}mm")
vsk.scale("1mm")

base_glyphs = [asemic_glyph() for _ in range(5)]

for j in range(grid_size):
    line_length = random.randint(4, grid_size)
    for i in range(line_length):
        x_offset = (j % 2) * (cell_size_x * 0.4)
        glyph = deepcopy(random.choice(base_glyphs))

        glyph = [(x + random.uniform(-0.1, 0.1), y + random.uniform(-0.1, 0.1)) for x, y in glyph]

        with vsk.pushMatrix():
            vsk.translate(i * cell_size_x + x_offset, j * cell_size_y)
            vsk.scale(scale_val)
            vsk.rotate(random.uniform(-0.3, 0.3))

            vsk.strokeWeight(random.randint(1, 3))

            vsk.polygon(glyph)

            if random.random() < 0.5:
                ghost_offset = 0.05
                vsk.polygon([(x + ghost_offset, y + ghost_offset) for x, y in glyph])

            if random.random() < 0.3:
                x = random.uniform(-0.3, 0.3)
                y = random.uniform(-0.3, 0.3)
                r = random.uniform(0.05, 0.2)
                vsk.line(x - r, y - r, x + r, y + r)

            if random.random() < 0.25:
                for _ in range(random.randint(1, 3)):
                    dx = random.uniform(-0.4, 0.4)
                    dy = random.uniform(-0.4, 0.4)
                    vsk.circle(dx, dy, random.uniform(0.05, 0.15))

            if random.random() < 0.2:
                lx = random.uniform(-0.3, 0.3)
                ly = random.uniform(-0.3, 0.3)
                vsk.line(lx, ly, lx + 0.2, ly + 0.05)

vsk.display()
